# %% [markdown]
# ### Hàm plot()được sử dụng để vẽ các điểm (điểm đánh dấu) trong sơ đồ.
#
# Theo mặc định, plot()hàm vẽ một đường từ điểm này sang điểm khác.
#
# Hàm lấy tham số để xác định các điểm trong sơ đồ.
#
# Tham số 1 là một mảng chứa các điểm trên trục x .
#
# Tham số 2 là một mảng chứa các điểm trên trục y .
#
# Nếu cần vẽ một đường từ (1, 3) đến (8, 10), chúng ta phải truyền hai mảng [1, 8] và [3, 10] vào hàm vẽ.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 8])
y = np.array([3, 10])
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Vẽ đồ thị không có đường kẻ
# Để chỉ vẽ các điểm đánh dấu, bạn có thể sử dụng tham số ký hiệu chuỗi phím tắt 'o', có nghĩa là 'vòng'.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([1, 8])
y = np.array([3, 10])
plt.plot(x, y,'o')
plt.show()

# %% [markdown]
# ### Nhiều điểm
# Bạn có thể vẽ bao nhiêu điểm tùy thích, chỉ cần đảm bảo rằng bạn có cùng số điểm trên cả hai trục.

# %%
x = np.array([1, 2, 4, 8])
y = np.array([4, 1, 8, 10])
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Điểm X mặc định
# Nếu chúng ta không chỉ định các điểm trên trục x, chúng sẽ nhận các giá trị mặc định 0, 1, 2, 3, v.v., tùy thuộc vào độ dài của điểm y.
#
# Vì vậy, nếu chúng ta lấy ví dụ tương tự như trên và bỏ đi các điểm x, sơ đồ sẽ trông như thế này:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# ### Điểm đánh dấu
# Bạn có thể sử dụng đối số từ khóa markerđể nhấn mạnh từng điểm bằng một điểm đánh dấu được chỉ định:
#
# ![image.png](data:image/png;base64,...)

# %%
# Đánh dấu từng điểm bằng một vòng tròn
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %% [markdown]
# ### Chuỗi định dạngfmt
# Bạn cũng có thể sử dụng tham số ký hiệu chuỗi phím tắt để chỉ định điểm đánh dấu.
#
# Tham số này còn được gọi fmtvà được viết theo cú pháp sau:
#
# marker | line | color : r, g , b , m , c, y , k , w
#
#
# ![image.png](data:image/png;base64,...)

# %%
ypoints = np.array([2,8, 1, 6])

plt.plot(ypoints, "3-.k")
plt.show()

# %% [markdown]
# ### Màu đánh dấu
# Bạn có thể sử dụng đối số từ khóa markeredgecolorhoặc ngắn hơn mecđể đặt màu cho cạnh của điểm đánh dấu:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
# Sử dụng cả đối số mecvà mfcđể tô màu toàn bộ điểm đánh dấu:
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

# %% [markdown]
# ### Kiểu đường nét
# Bạn có thể sử dụng từ khóa đối số (linestyle ) hoặc ngắn hơn (ls) để thay đổi kiểu của đường vẽ:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %% [markdown]
# ### Màu đường kẻ
# Bạn có thể sử dụng đối số từ khóa colorhoặc ngắn hơn cđể đặt màu của dòng:

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# ### Nhiều dòng
# Bạn có thể vẽ bao nhiêu dòng tùy thích bằng cách thêm nhiều plt.plot()chức năng hơn:

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# ### Bạn cũng có thể vẽ nhiều đường bằng cách cộng các điểm cho trục x và y cho mỗi đường trong cùng một plt.plot()hàm.
#
# (Trong các ví dụ trên, chúng tôi chỉ xác định các điểm trên trục y, nghĩa là các điểm trên trục x có giá trị mặc định (0, 1, 2, 3).)
#
# Các giá trị x và y đi theo cặp:
#
# Ví dụ

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])

x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# ### Tạo nhãn cho ô
# Với Pyplot, bạn có thể sử dụng các hàm xlabel() và  ylabel() để đặt nhãn cho trục x và y.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ### Tạo tiêu đề cho cốt truyện
# Với Pyplot, bạn có thể sử dụng title()hàm để đặt tiêu đề cho cốt truyện.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# ### Đặt thuộc tính phông chữ cho tiêu đề và nhãn
# Bạn có thể sử dụng (fontdict) tham số trong xlabel(), ylabel()và title()để đặt thuộc tính phông chữ cho tiêu đề và nhãn.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Định vị Tiêu đề
# Bạn có thể sử dụng **loc** tham số title() để định vị tiêu đề.
#
# Các giá trị pháp lý là: 'trái', 'phải' và 'giữa'. Giá trị mặc định là 'trung tâm'.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'size': 20}
plt.title("Sports Watch Data", loc = 'center', fontdict= font1)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Thêm đường lưới vào đồ thị
#  Với Pyplot, bạn có thể sử dụng grid()hàm để thêm đường lưới vào biểu đồ.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# ### Chỉ định đường lưới nào sẽ hiển thị
# Bạn có thể sử dụng axistham số trong grid()hàm để chỉ định đường lưới nào sẽ hiển thị.
#
# Các giá trị pháp lý là: 'x', 'y' và 'cả hai'. Giá trị mặc định là 'cả hai'.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %% [markdown]
# ### Đặt thuộc tính dòng cho lưới
# Bạn cũng có thể đặt thuộc tính đường của lưới, như sau: Grid(color = ' color ', linestyle = ' linestyle ', linewidth = number ).

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '-.', linewidth = 0.5)

plt.show()

# %% [markdown]
# ### Hiển thị nhiều ô
# Với subplot()chức năng này, bạn có thể vẽ nhiều ô trong một hình:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Hàm subplot()
# Hàm này subplot()có ba đối số mô tả bố cục của hình.
#
# Bố cục được sắp xếp theo hàng và cột, được biểu thị bằng đối số thứ nhất và thứ hai .
#
# Đối số thứ ba đại diện cho chỉ mục của biểu đồ hiện tại.
#
# plt.subplot(1, 2, 1)
# #the figure has 1 row, 2 columns, and this plot is the first plot.
#
# plt.subplot(1, 2, 2)
# #the figure has 1 row, 2 columns, and this plot is the second plot.
# Vì vậy, nếu chúng ta muốn một hình có 2 hàng một cột (nghĩa là hai ô sẽ được hiển thị chồng lên nhau thay vì cạnh nhau), chúng ta có thể viết cú pháp như sau:

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1) # Có 2 hàng 3 cột và plot first
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES") # Thêm tiêu đồ cho mỗi plot

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP") # Title đại diện cho all plot
plt.show()

# %% [markdown]
# ### Tạo đồ thị phân tán
# Với Pyplot, bạn có thể sử dụng scatter()hàm để vẽ biểu đồ phân tán.
#
# Hàm **scatter()** vẽ một dấu chấm cho mỗi quan sát. Nó cần hai mảng có cùng độ dài, một mảng cho các giá trị của trục x và một mảng cho các giá trị trên trục y:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Quan sát trong ví dụ trên là kết quả của 13 ô tô đi ngang qua.
#
# Trục X hiển thị tuổi thọ của xe.
#
# Trục Y hiển thị tốc độ của ô tô khi đi qua.
#
# Có mối quan hệ nào giữa các quan sát không?
#
# Có vẻ như xe càng mới thì chạy càng nhanh nhưng đó có thể chỉ là trùng hợp thôi, dù sao chúng tôi cũng chỉ đăng ký 13 xe.
#
# So sánh các ô
#
# Trong ví dụ trên, dường như có mối quan hệ giữa tốc độ và tuổi tác, nhưng điều gì sẽ xảy ra nếu chúng ta vẽ đồ thị các quan sát từ một ngày khác? Biểu đồ phân tán có cho chúng ta biết điều gì khác không?

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink') # color Thêm màu

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
# Đặt màu riêng cho từng chấm

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ### Bản đồ màu
# Mô-đun Matplotlib có một số bản đồ màu có sẵn.
#
# Bản đồ màu giống như một danh sách các màu, trong đó mỗi màu có giá trị nằm trong khoảng từ 0 đến 100.
#
# Đây là một ví dụ về bản đồ màu:
# ![image.png](data:image/png;base64,...)
#
#
#
# Bản đồ màu này được gọi là 'viridis' và như bạn có thể thấy, nó nằm trong khoảng từ 0, là màu tím, đến 100, là màu vàng.
#
# Cách sử dụng Bản đồ màu
#
# Bạn có thể chỉ định bản đồ màu với đối số từ khóa cmapcó giá trị của bản đồ màu, trong trường hợp 'viridis'này là một trong những bản đồ màu tích hợp sẵn có trong Matplotlib.
#
# Ngoài ra, bạn phải tạo một mảng có các giá trị (từ 0 đến 100), một giá trị cho mỗi điểm trong biểu đồ phân tán:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %% [markdown]
# ### **Bản đồ màu có sẵn: **
#
# ![image.png](data:image/png;base64,...)

# %%
# Bạn có thể đưa bản đồ màu vào bản vẽ bằng cách đưa vào plt.colorbar()

import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='Accent_r')

plt.colorbar()

plt.show()

# %% [markdown]
# ### Kích cỡ
# Bạn có thể thay đổi kích thước của các dấu chấm bằng sđối số.
#
# Cũng giống như màu sắc, hãy đảm bảo mảng cho kích thước có cùng độ dài với mảng cho trục x và y:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5) # Chỉnh độ trong suốt bằng đối số alpha

plt.show()

# %% [markdown]
# ### Kết hợp kích thước màu và Alpha
# Bạn có thể kết hợp bản đồ màu với các kích thước khác nhau của dấu chấm. Điều này được hình dung tốt nhất nếu các dấu chấm trong suốt:

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))

sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# ### Tạo Biểu Đồ
# Với Pyplot, bạn có thể sử dụng **bar()** hàm để vẽ biểu đồ thanh:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y) # barh thanh hiển thị theo phương ngang
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "red") # thêm màu cho thanh

plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.1) # Đặt kính thước cho thanh

plt.show() # Lưu ý: Đối với các thanh ngang sử dụng heightthay vì width.

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height= 0.1) # Đặt kính thước cho thanh

plt.show() # Lưu ý: Đối với các thanh ngang sử dụng heightthay vì width.

# %% [markdown]
# ### Tạo biểu đồ
# Trong Matplotlib, chúng tôi sử dụng hist() hàm để tạo biểu đồ.
#
# Hàm hist() sẽ sử dụng một mảng số để tạo biểu đồ, mảng đó được gửi vào hàm dưới dạng đối số.
#
# Để đơn giản, chúng tôi sử dụng NumPy để tạo ngẫu nhiên một mảng có 250 giá trị, trong đó các giá trị sẽ tập trung vào khoảng 170 và độ lệch chuẩn là 10. Tìm hiểu thêm về Phân phối dữ liệu thông thường trong Hướng dẫn học máy của chúng tôi .

# %%
import numpy as np

x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [163.52122827 166.91179015 162.0987441  167.50865999 162.32304629
#  175.2832545  175.64667203 194.57999563 179.99531384 164.44054043
#  171.41370537 154.452538   159.22354789 175.99649386 166.6626239
#  186.58968703 162.83077848 159.0016302  176.51912548 162.53874092
#  169.2107835  174.62319367 174.2185934  160.54787897 179.50321279
#  172.54820544 172.54570056 166.4132425  166.91258189 168.44419609
#  180.64188948 186.6661627  170.19227688 158.58832653 180.96501282
#  163.94555919 158.23984597 167.93448591 175.57541943 172.27714297
#  167.24495286 175.15974387 171.43309216 167.29233492 163.92222881
#  161.68273127 162.20112527 170.15792752 177.03106906 188.31468559
#  172.43578133 175.04822553 178.23090499 176.63438124 168.6721975
#  159.55923022 184.42021397 147.23661192 156.2893899  179.73159698
#  194.58186866 162.61690559 169.96373653 178.23718865 175.38257992
#  187.45177086 165.84758239 149.47423407 172.14991153 172.40073008
# ...

# %%
plt.hist(x) # Hàm hist dùng để đọc mảng và tạo biểu đồ trên
plt.show()

# %% [markdown]
# ### Tạo biểu đồ hình tròn
# Với Pyplot, bạn có thể sử dụng pie()hàm để vẽ biểu đồ hình tròn:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Nhãn
# Thêm nhãn vào biểu đồ hình tròn bằng labelstham số.
#
# Tham **labels **số phải là một mảng có một nhãn cho mỗi phần:

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Mảng Rời
# Có lẽ bạn muốn một trong những chiếc nêm nổi bật? Tham   **explode ** số cho phép bạn làm điều đó.
#
# Tham **explode** số, nếu được chỉ định chứ không phải None, phải là một mảng có một giá trị cho mỗi phần.
#
# Mỗi giá trị biểu thị khoảng cách từ trung tâm mỗi nêm được hiển thị:

# %%
y = np.array([35, 25, 25, 15])

mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True) # Thêm bóng bằng hàm shadow
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors) # Thêm màu sắc
plt.show()

# %% [markdown]
# ### Mục gợi ý
# Để thêm danh sách giải thích cho từng phần, hãy sử dụng **legend()**  hàm:

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:") # Thêm title giải thích
plt.show()

# %% [markdown]
# Để di chuyển chú thích (legend) sang vị trí mong muốn (trên, dưới, trái hoặc phải), bạn có thể sử dụng tham số loc trong hàm plt.legend(). Dưới đây là cách bạn có thể di chuyển chú thích:
#
# Để chú thích nằm ở trên: plt.legend(loc='upper center')
#
# Để chú thích nằm ở dưới: plt.legend(loc='lower center')
#
# Để chú thích nằm ở trái: plt.legend(loc='center left')
#
# Để chú thích nằm ở phải: plt.legend(loc='center right')

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:", loc='upper left') # Di chuyển legend
plt.show()
